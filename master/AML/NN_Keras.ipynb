# %% [markdown]
# <img src="https://s3.amazonaws.com/keras.io/img/keras-logo-2018-large-1200.png" width="20%" />
#
# # Keras: Deep Learning library for TensorFlow

# %% [markdown]
# >Keras is a minimalist, highly modular neural networks library, written in Python and capable of running on top TensorFlow.
#
# >It was developed with a focus on enabling fast experimentation. Being able to go from idea to result with the least possible delay is key to doing good research.
# ref: https://keras.io/

# %% [markdown]
# # First part
# ## 🍔 First Neural Network with Keras

# %%
from tensorflow.keras.utils import to_categorical
from keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt

# %%
def preprocess_mnist(x_train, y_train):
  x_train = x_train.reshape(x_train.shape[0], 28*28)
  x_train = x_train.astype('float32')
  x_train /= 255
  y_train = to_categorical(y_train)
  return x_train, y_train

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

plt.imshow(x_train[2].reshape(28, 28), cmap='gray')

x_train, y_train = preprocess_mnist(x_train, y_train)
x_test, y_test = preprocess_mnist(x_test, y_test)

# %% [markdown]
# ### Building blocks (Sequantial API)
#
#
#
# *   Dense = Fully connected layer ([Official docs](https://keras.io/api/layers/core_layers/dense/))
# *   Activation = Activation function ([Official docs](https://keras.io/api/layers/activations/))
# * Sequential = Group a set of layers sequentially ([Official docs](https://keras.io/api/models/sequential/))

# %%
from keras import Sequential
from keras.layers import Dense, Activation, Input
from keras import activations

model = Sequential()

model.add(Input((28*28,)))
model.add(Dense(32, activation=activations.relu))
model.add(Dense(16, activation=activations.relu))
model.add(Dense(10, activation=activations.relu))
model.add(Dense(10))
model.add(Activation(activation=activations.softmax))

# %% [markdown]
# ### Inspect the model structure

# %%
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_20 (Dense)                │ (None, 32)             │        25,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 10)             │           170 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 10)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,928 (101.28 KB)
#  Trainable params: 25,928 (101.28 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Compile the model
#
# It is mandatory to compile a Keras model before training or using it! This function also requires some additional parameters:
#
# * optimizer = Training optimizer ([Official docs](https://keras.io/api/optimizers/))
# * loss = Loss function ([Official docs](https://keras.io/api/losses/))
# * metrics = Metrics to be monitored during training ([Official docs](https://keras.io/api/metrics/))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ### Train the model
#
# And then train it!

# %%
model.fit(x_train, y_train, epochs=20, batch_size=128, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9844 - loss: 0.0518 - val_accuracy: 0.9640 - val_loss: 0.1474
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9859 - loss: 0.0468 - val_accuracy: 0.9636 - val_loss: 0.1448
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9867 - loss: 0.0452 - val_accuracy: 0.9595 - val_loss: 0.1686
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9869 - loss: 0.0443 - val_accuracy: 0.9632 - val_loss: 0.1543
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9871 - loss: 0.0414 - val_accuracy: 0.9628 - val_loss: 0.1558
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9889 - loss: 0.0389 - val_accuracy: 0.9623 - val_loss: 0.1595
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9887 - loss: 0.0368 - val_accuracy: 0.9628 - val_loss: 0.1614
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9891 - loss: 0.0366 - val_accuracy: 0.9629 - val_loss: 0.1659
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9889 - loss: 0.0351 - val_accuracy: 0.9603 - val_loss: 0.1775
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9902 - loss: 0.0320 - val_accuracy: 0.9636 - val_loss: 0.1701
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9908 - loss: 0.0304 - val_accuracy: 0.9624 - val_loss: 0.1702
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9904 - loss: 0.0310 - val_accuracy: 0.9622 - val_loss: 0.1740
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9919 - loss: 0.0275 - val_accuracy: 0.9597 - val_loss: 0.1871
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9914 - loss: 0.0283 - val_accuracy: 0.9628 - val_loss: 0.1743
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9921 - loss: 0.0258 - val_accuracy: 0.9612 - val_loss: 0.1905
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9923 - loss: 0.0245 - val_accuracy: 0.9602 - val_loss: 0.1998
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9936 - loss: 0.0225 - val_accuracy: 0.9590 - val_loss: 0.2074
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9930 - loss: 0.0234 - val_accuracy: 0.9621 - val_loss: 0.1915
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9935 - loss: 0.0220 - val_accuracy: 0.9575 - val_loss: 0.2113
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9933 - loss: 0.0225 - val_accuracy: 0.9620 - val_loss: 0.1950

# %% [markdown]
# ### Predict

# %%
int_predictions = np.argmax(predictions, axis=1)

print(int_predictions[:10])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# [7 2 1 0 4 1 4 9 6 9]

# %% [markdown]
# ### Evaluate the model
#
# (use scikit-learn functions)

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9623 - loss: 0.1827
# [0.18265320360660553, 0.9623000025749207]

# %% [markdown]
# Primo risultato dell'evaluate loss
# Secondi risultato dell'evaluate accuracy

# %% [markdown]
# ## ⭐ Hyperparameters

# %%
from keras.utils import to_categorical
from keras.datasets import mnist

def preprocess_mnist(x_train, y_train):
  x_train = x_train.reshape(x_train.shape[0], 28*28)
  x_train = x_train.astype('float32')
  x_train /= 255
  y_train = to_categorical(y_train)
  return x_train, y_train

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train, y_train = preprocess_mnist(x_train, y_train)
x_test, y_test = preprocess_mnist(x_test, y_test)

# %% [markdown]
# # Second part
#
# ### 🍔 Build the network
#
# Hyperparameters:
#
# * **optimizer**
# * **learning_rate** = controls how much the model's weights are adjusted with respect to the gradient during each training step.
#
# ### Effects of learning rate value
#
# ![0_a2DcKhke63IMowJB.png](data:image/png;base64,...)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import SGD

dims = x_train.shape[1]
print('Input Shape =', dims)

nb_classes = y_train.shape[1]
print('Number classes = Output Shape =', nb_classes)

model = Sequential()
model.add(Input((dims,)))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(nb_classes, activation='softmax'))

optimizer = SGD(learning_rate=0.001)

model.compile(optimizer=optimizer, loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Input Shape = 784
# Number classes = Output Shape = 10

# %% [markdown]
# ### 🏋 Training
#
# Hyperparameters:
#
# * **batch_size** = dimension of the batch during (number of training elements considered before updating the weights during backpropagation).
# * **epochs** = number of times the training is repeated.
# * **validation_split** = percentage of the dimension of the validation set (it is also possible to specify the validation set itself)

# %%
history = model.fit(x_train, y_train, batch_size=128, epochs=50, validation_split=0.1)
# Out:
# Epoch 1/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1852 - loss: 2.2295 - val_accuracy: 0.3092 - val_loss: 2.1455
# Epoch 2/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3976 - loss: 2.0702 - val_accuracy: 0.5010 - val_loss: 1.9610
# Epoch 3/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5312 - loss: 1.8714 - val_accuracy: 0.6140 - val_loss: 1.7290
# Epoch 4/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6289 - loss: 1.6319 - val_accuracy: 0.6917 - val_loss: 1.4665
# Epoch 5/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6901 - loss: 1.3829 - val_accuracy: 0.7408 - val_loss: 1.2163
# Epoch 6/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7291 - loss: 1.1645 - val_accuracy: 0.7830 - val_loss: 1.0129
# Epoch 7/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7620 - loss: 0.9951 - val_accuracy: 0.8118 - val_loss: 0.8608
# Epoch 8/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7872 - loss: 0.8698 - val_accuracy: 0.8338 - val_loss: 0.7488
# Epoch 9/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8053 - loss: 0.7768 - val_accuracy: 0.8473 - val_loss: 0.6652
# Epoch 10/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8182 - loss: 0.7063 - val_accuracy: 0.8555 - val_loss: 0.6020
# Epoch 11/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8288 - loss: 0.6515 - val_accuracy: 0.8650 - val_loss: 0.5525
# Epoch 12/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8380 - loss: 0.6081 - val_accuracy: 0.8717 - val_loss: 0.5134
# Epoch 13/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8452 - loss: 0.5734 - val_accuracy: 0.8780 - val_loss: 0.4826
# Epoch 14/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8518 - loss: 0.5451 - val_accuracy: 0.8825 - val_loss: 0.4572
# Epoch 15/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8571 - loss: 0.5214 - val_accuracy: 0.8873 - val_loss: 0.4361
# Epoch 16/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8618 - loss: 0.5012 - val_accuracy: 0.8937 - val_loss: 0.4187
# Epoch 17/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8659 - loss: 0.4841 - val_accuracy: 0.8948 - val_loss: 0.4031
# Epoch 18/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8692 - loss: 0.4690 - val_accuracy: 0.8963 - val_loss: 0.3894
# Epoch 19/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8724 - loss: 0.4558 - val_accuracy: 0.8983 - val_loss: 0.3780
# Epoch 20/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8756 - loss: 0.4439 - val_accuracy: 0.9013 - val_loss: 0.3676
# Epoch 21/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8781 - loss: 0.4333 - val_accuracy: 0.9020 - val_loss: 0.3584
# Epoch 22/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8802 - loss: 0.4238 - val_accuracy: 0.9035 - val_loss: 0.3497
# Epoch 23/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8823 - loss: 0.4150 - val_accuracy: 0.9043 - val_loss: 0.3423
# Epoch 24/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8846 - loss: 0.4070 - val_accuracy: 0.9080 - val_loss: 0.3351
# Epoch 25/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8861 - loss: 0.3997 - val_accuracy: 0.9088 - val_loss: 0.3288
# Epoch 26/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8881 - loss: 0.3928 - val_accuracy: 0.9110 - val_loss: 0.3235
# Epoch 27/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8890 - loss: 0.3865 - val_accuracy: 0.9123 - val_loss: 0.3174
# Epoch 28/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8909 - loss: 0.3807 - val_accuracy: 0.9130 - val_loss: 0.3123
# Epoch 29/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8927 - loss: 0.3752 - val_accuracy: 0.9132 - val_loss: 0.3080
# Epoch 30/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8940 - loss: 0.3699 - val_accuracy: 0.9152 - val_loss: 0.3032
# Epoch 31/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8951 - loss: 0.3650 - val_accuracy: 0.9153 - val_loss: 0.2990
# Epoch 32/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8957 - loss: 0.3603 - val_accuracy: 0.9168 - val_loss: 0.2952
# Epoch 33/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8976 - loss: 0.3559 - val_accuracy: 0.9165 - val_loss: 0.2912
# Epoch 34/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8988 - loss: 0.3516 - val_accuracy: 0.9193 - val_loss: 0.2876
# Epoch 35/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8996 - loss: 0.3476 - val_accuracy: 0.9188 - val_loss: 0.2846
# Epoch 36/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9009 - loss: 0.3437 - val_accuracy: 0.9207 - val_loss: 0.2817
# Epoch 37/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9019 - loss: 0.3401 - val_accuracy: 0.9213 - val_loss: 0.2781
# Epoch 38/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9028 - loss: 0.3366 - val_accuracy: 0.9223 - val_loss: 0.2754
# Epoch 39/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9038 - loss: 0.3332 - val_accuracy: 0.9233 - val_loss: 0.2726
# Epoch 40/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9051 - loss: 0.3299 - val_accuracy: 0.9252 - val_loss: 0.2695
# Epoch 41/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9058 - loss: 0.3267 - val_accuracy: 0.9250 - val_loss: 0.2671
# Epoch 42/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9067 - loss: 0.3237 - val_accuracy: 0.9255 - val_loss: 0.2645
# Epoch 43/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9074 - loss: 0.3206 - val_accuracy: 0.9257 - val_loss: 0.2625
# Epoch 44/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9082 - loss: 0.3179 - val_accuracy: 0.9270 - val_loss: 0.2595
# Epoch 45/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9094 - loss: 0.3151 - val_accuracy: 0.9278 - val_loss: 0.2571
# Epoch 46/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9101 - loss: 0.3124 - val_accuracy: 0.9283 - val_loss: 0.2553
# Epoch 47/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9106 - loss: 0.3098 - val_accuracy: 0.9295 - val_loss: 0.2531
# Epoch 48/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9116 - loss: 0.3072 - val_accuracy: 0.9305 - val_loss: 0.2509
# Epoch 49/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9121 - loss: 0.3047 - val_accuracy: 0.9303 - val_loss: 0.2487
# Epoch 50/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9126 - loss: 0.3023 - val_accuracy: 0.9313 - val_loss: 0.2469

# %% [markdown]
# ### 📊 Monitor training performance
#
# It is usually useful to monitor performance during training to understand which hyperparameters need to be adjusted.

# %%
import matplotlib.pyplot as plt

def plot_loss(history):
  x_plot = list(range(1,len(history.history["loss"])+1))
  plt.figure()
  plt.title("Loss")
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.plot(x_plot, history.history['loss'])
  plt.plot(x_plot, history.history['val_loss'])
  plt.legend(['Training', 'Validation'])

def plot_accuracy(history):
  x_plot = list(range(1,len(history.history["accuracy"])+1))
  plt.figure()
  plt.title("Accuracy")
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.plot(x_plot, history.history['accuracy'])
  plt.plot(x_plot, history.history['val_accuracy'])
  plt.legend(['Training', 'Validation'])

# %%
#NOTE: history is the object returned by the fit function!

plot_loss(history)
plot_accuracy(history)

# %% [markdown]
# ### Examples
#
# ![1_I16ywET-JG2tu8iGlMTryA.png](data:image/png;base64,...)![Training-and-Validation-overfitting-and-learning-rate-of-sample-image.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 📕 Exercise
#
# Take the dataset on elearning (from Kaggle) or one of the datasets available in keras ([here](https://keras.io/api/datasets/)) and play a bit with neural networks:
#
#
#
# * Add some layers.
# * Assign an activation function to each of them.
# * Choose the values of the hyperparameters (batch_size, optimizer, learning_rate, epochs).
# * Monitor the performance on a validation set and observe how the shape of the plot changes as one hyperparameter at a time is changed.
# * Calculate the performance on the test set.

# %% [markdown]
# ## Kaggle Challenge Data

# %% [markdown]
# >The Otto Group is one of the world’s biggest e-commerce companies, A consistent analysis of the performance of products is crucial. However, due to diverse global infrastructure, many identical products get classified differently.
# For this competition, we have provided a dataset with 93 features for more than 200,000 products. The objective is to build a predictive model which is able to distinguish between our main product categories.
# Each row corresponds to a single product. There are a total of 93 numerical features, which represent counts of different events. All features have been obfuscated and will not be defined any further.
#
# https://www.kaggle.com/c/otto-group-product-classification-challenge/data

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# ### Utility functions
#
# Utility functions to load Kaggle Otto Group Challenge Data.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical



def load_data(path, train=True):
    """Load data from a CSV File

    Parameters
    ----------
    path: str
        The path to the CSV file

    train: bool (default True)
        Decide whether or not data are *training data*.
        If True, some random shuffling is applied.

    Return
    ------
    X: numpy.ndarray
        The data as a multi dimensional array of floats
    ids: numpy.ndarray
        A vector of ids for each sample
    """
    text = pd.read_csv(path, encoding = "ISO-8859-2")
    df = pd.read_csv(path)
    X = df.values.copy()
    if train:
        np.random.shuffle(X)
        X, labels = X[:, 1:-1].astype(np.float32), X[:, -1]
        return X, labels
    else:
        X, ids = X[:, 1:].astype(np.float32), X[:, 0].astype(str)
        return X, ids


def preprocess_data(X, scaler=None):
    """Preprocess input data by standardise features
    by removing the mean and scaling to unit variance"""
    if not scaler:
        scaler = StandardScaler()
        scaler.fit(X)
    X = scaler.transform(X)
    return X, scaler


def preprocess_labels(labels, encoder=None, categorical=True):
    """Encode labels with values among 0 and `n-classes-1`"""
    if not encoder:
        encoder = LabelEncoder()
        encoder.fit(labels)
    y = encoder.transform(labels).astype(np.int32)
    if categorical:
        y = to_categorical(y)
    return y, encoder

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import data

# %%
url_train = 'https://raw.githubusercontent.com/leriomaggio/deep-learning-keras-tensorflow/master/data/kaggle_ottogroup/train.csv'
url_test = 'https://raw.githubusercontent.com/leriomaggio/deep-learning-keras-tensorflow/master/data/kaggle_ottogroup/test.csv'
X_train, labels = load_data(url_train, train=True)

print("Training set data")
print(X_train)

print("Training set labels")
print(labels)

# %% [markdown]
# ### Preprocess data

# %%
X_train, labels = load_data(url_train, train=True)
X_train, scaler = preprocess_data(X_train)
Y_train, encoder = preprocess_labels(labels)

X_test, ids = load_data(url_test, train=False)
X_test, _ = preprocess_data(X_test, scaler)

nb_classes = Y_train.shape[1]
print(nb_classes, 'classes')

dims = X_train.shape[1]
print(X_train.shape, 'dims Training set')
